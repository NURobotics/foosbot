# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
initial_image_png = "cropped_image.png"
points = np.genfromtxt('points.csv', delimiter=',', names=True)
len(points)
# Out:
# 14

# %%
img = cv.imread(initial_image_png, cv.IMREAD_GRAYSCALE)
plt.imshow(img, cmap="gray")

# %%
thresh, bwImage = cv.threshold(img, 100, 255, cv.THRESH_BINARY)
plt.imshow(bwImage, cmap="gray")

# %%
params = cv.SimpleBlobDetector_Params()
params.minThreshold = 10
params.maxThreshold = 200

# params.filterByArea = True
params.minArea = 10

# # Filter by Circularity
# params.filterByCircularity = True
# params.minCircularity = 0.1

# # Filter by Convexity
params.filterByConvexity = True
params.minConvexity = 0.87

# # Filter by Inertia
# params.filterByInertia = True
# params.minInertiaRatio = 0.01


detector = cv.SimpleBlobDetector_create(params)
keypoints = detector.detect(bwImage)
len(keypoints)
# Out:
# 14

# %%
im_with_keypoints = cv.drawKeypoints(bwImage, keypoints, np.array([]), (0,0,255), cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)

# %%
circleImg = np.ones((bwImage.shape)) * 255
for i, keypoint in enumerate(keypoints):
    center = (int(keypoint.pt[0]), int(keypoint.pt[1]))
    cv.circle(circleImg, center, 25, 0, -1)
    print(i, keypoint.pt[0], keypoint.pt[1])
fig, axs = plt.subplots(1, 3)
axs[0].imshow(img, cmap="gray")
axs[1].imshow(circleImg, cmap="gray")
axs[2].imshow(im_with_keypoints, cmap="gray")
# Out:
# 0 1184.7781982421875 2384.61279296875
# 1 104.20716857910156 2037.465576171875
# 2 948.7808837890625 2028.4310302734375
# 3 1659.990478515625 1779.2113037109375
# 4 484.34344482421875 1777.8792724609375
# 5 1186.8853759765625 1672.99072265625
# 6 1031.2298583984375 1434.42529296875
# 7 1188.38427734375 1436.89013671875
# 8 484.30010986328125 1426.6927490234375
# 9 1420.55029296875 1104.725341796875
# 10 959.3040161132812 1091.6173095703125
# 11 354.4223937988281 1074.2109375
# 12 479.2001953125 590.0936279296875
# 13 1191.9061279296875 490.5137023925781
